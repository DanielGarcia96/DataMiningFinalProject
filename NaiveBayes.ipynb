# %%
# Abbreviations:
# DS: data set
# df: data frame
import csv
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.naive_bayes import GaussianNB
from sklearn import preprocessing

# Map string attributes to integer values
def map_stringAttributes(df, attr_hash):
    df_new = df.copy()
    le = preprocessing.LabelEncoder()
    #new_features = []
    #print("* len(df.columns)", len(df.columns), sep="\n", end="\n\n")
    for i in range (0, len(df.columns)-1, 1):
        attr_name = df.columns[i]                      # attribute name
        value = df.iloc[0][attr_name]                  # first value in column
        if (isinstance(value, str) == True):           # check if value is a string
            attr_values = df_new[attr_name].unique()   # unique values for attribute
            # map integers for each unique attribute value
            map_to_int = {name: n for n, name in enumerate(attr_values)}
            # replace data in dataset with its respective int
            df_new[attr_name] = df_new[attr_name].replace(map_to_int)
            # store list of attribute values and their int mapping to attribute name
            attr_hash[attr_name] = list(enumerate(attr_values))
            #print("* attr_hash[attr_name]", attr_hash[attr_name], end="\n\n")
    # view of new dataset with integer mapping
    print("* New data frame head:", df_new.head(20), end="\n\n")
    return (df_new, attr_hash)
        

# Data frames for their respective data set
adult_df = pd.read_csv("Adult_DS.csv")
boston_df = load_boston()

# Naive Bayes Classifier
# Create list of features for adult DS
adult_features = list(adult_df.columns[:14])
# This is just to show everything is working
print("* features:", adult_features, sep="\n", end="\n\n")
print("* classes:", adult_classes, sep="\n", end="\n\n")

# hash table for attributes
attributes = {}
adult_df, attributes = map_stringAttributes(adult_df, attributes)

adult_y = adult_df["annual-income"]        # class label
adult_X = adult_df[adult_features]         # features

gnb = GaussianNB()
# fit dataset
naive_bayes = gnb.fit(adult_X, adult_y)
# Out:
# * features:
# ['age', 'workclass', 'final-weight', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country']
#
# * classes:
# ['<=50K' '>50K']
#
# * New data frame head:     age  workclass  final-weight  education  education-num  marital-status  \
# 0    39          0         77516          0             13               0
# 1    50          1         83311          0             13               1
# 2    38          2        215646          1              9               2
# 3    53          2        234721          2              7               1
# 4    28          2        338409          0             13               1
# 5    37          2        284582          3             14               1
# 6    49          2        160187          4              5               3
# 7    52          1        209642          1              9               1
# ...
